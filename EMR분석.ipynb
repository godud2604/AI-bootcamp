# %% [markdown]
# <a href="https://colab.research.google.com/github/godud2604/AI-bootcamp/blob/main/EMR%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH = '/content/drive/MyDrive/biodata/mimic-iii-clinical-database-demo-1.4/'

# %%
import pandas as pd

# %%
patients = pd.read_csv(PATH+"PATIENTS.csv", index_col=0)
admissions = pd.read_csv(PATH+"ADMISSIONS.csv", index_col=0)
diagnose_icd = pd.read_csv(PATH+"DIAGNOSES_ICD.csv", index_col=0)
icustays = pd.read_csv(PATH+"ICUSTAYS.csv", index_col=0)
d_icd_diagnoses = pd.read_csv(PATH+"D_ICD_DIAGNOSES.csv", index_col=0)
chartevents = pd.read_csv(PATH+"CHARTEVENTS.csv", index_col=0)
# Out:
# <ipython-input-102-93118852c45d>:6: DtypeWarning: Columns (8,10,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   chartevents = pd.read_csv(PATH+"CHARTEVENTS.csv", index_col=0)

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 9467 to 31872
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   subject_id   100 non-null    int64
#  1   gender       100 non-null    object
#  2   dob          100 non-null    object
#  3   dod          100 non-null    object
#  4   dod_hosp     70 non-null     object
#  5   dod_ssn      77 non-null     object
#  6   expire_flag  100 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 6.2+ KB

# %%
patients.nunique()
# Out:
# subject_id     100
# gender           2
# dob             99
# dod            100
# dod_hosp        70
# dod_ssn         77
# expire_flag      1
# dtype: int64

# %%
patients['subject_id']
# Out:
# row_id
# 9467     10006
# 9472     10011
# 9474     10013
# 9478     10017
# 9479     10019
#          ...
# 31838    44083
# 31853    44154
# 31867    44212
# 31870    44222
# 31872    44228
# Name: subject_id, Length: 100, dtype: int64

# %%
patients['gender'].value_counts()
# Out:
# F    55
# M    45
# Name: gender, dtype: int64

# %%
patients.columns
# Out:
# Index(['subject_id', 'gender', 'dob', 'dod', 'dod_hosp', 'dod_ssn',
#        'expire_flag'],
#       dtype='object')

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129 entries, 12258 to 41092
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_id            129 non-null    int64
#  1   hadm_id               129 non-null    int64
#  2   admittime             129 non-null    object
#  3   dischtime             129 non-null    object
#  4   deathtime             40 non-null     object
#  5   admission_type        129 non-null    object
#  6   admission_location    129 non-null    object
#  7   discharge_location    129 non-null    object
#  8   insurance             129 non-null    object
#  9   language              81 non-null     object
#  10  religion              128 non-null    object
#  11  marital_status        113 non-null    object
#  12  ethnicity             129 non-null    object
#  13  edregtime             92 non-null     object
#  14  edouttime             92 non-null     object
#  15  diagnosis             129 non-null    object
#  16  hospital_expire_flag  129 non-null    int64
#  17  has_chartevents_data  129 non-null    int64
# dtypes: int64(4), object(14)
# memory usage: 19.1+ KB

# %%
len(d_icd_diagnoses)
# Out:
# 14567

# %%
len(diagnose_icd)
# Out:
# 1761

# %%
diagnose_icd.columns
# Out:
# Index(['subject_id', 'hadm_id', 'seq_num', 'icd9_code'], dtype='object')

# %%
d_icd_diagnoses.columns
# Out:
# Index(['icd9_code', 'short_title', 'long_title'], dtype='object')

# %%
d1 = pd.merge(diagnose_icd, d_icd_diagnoses, on='icd9_code')[['subject_id', 'hadm_id', 'seq_num', 'icd9_code', 'short_title']]
d1
# Out:
#       subject_id  hadm_id  seq_num icd9_code               short_title
# 0          10006   142345        1     99591                    Sepsis
# 1          10038   111115        6     99591                    Sepsis
# 2          10088   149044        2     99591                    Sepsis
# 3          10124   170883       12     99591                    Sepsis
# 4          10132   197611        4     99591                    Sepsis
# ...          ...      ...      ...       ...                       ...
# 1711       44222   192189        3     E9429    Adv eff cardiovasc NEC
# 1712       44228   103379        1     03842         E coli septicemia
# 1713       44228   103379        6      1561  Mal neo extrahepat ducts
# 1714       44228   103379        7      1975    Sec malig neo lg bowel
# 1715       44228   103379        8     45182  Phlbts sprfc vn up extrm
#
# [1716 rows x 5 columns]

# %%
d1.short_title.value_counts()
# Out:
# Hypertension NOS            53
# Atrial fibrillation         48
# Acute kidney failure NOS    45
# CHF NOS                     39
# Acute respiratry failure    31
#                             ..
# Nystagmus NOS                1
# Nasal bone fx-closed         1
# Open wound of scalp          1
# Oth coll stndng obj-psgr     1
# Phlbts sprfc vn up extrm     1
# Name: short_title, Length: 561, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
p = d1.short_title.value_counts().sort_values()
p[ p >= 20 ].plot(kind="barh")
plt.show()

# %%
len(d1)
# Out:
# 1716

# %%
d1.columns
# Out:
# Index(['subject_id', 'hadm_id', 'seq_num', 'icd9_code', 'short_title'], dtype='object')

# %%
g = d1.groupby([ 'subject_id' ])
g

# %%
list(g)[0]
# Out:
# <ipython-input-120-9c863bac1798>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   list(g)[0]
# (10006,
#       subject_id  hadm_id  seq_num icd9_code               short_title
#  0         10006   142345        1     99591                    Sepsis
#  10        10006   142345        2     99662  React-oth vasc dev/graft
#  13        10006   142345        4     40391    Hyp kid NOS w cr kid V
#  20        10006   142345        5     42731       Atrial fibrillation
#  68        10006   142345        6      4280                   CHF NOS
#  107       10006   142345        7      4241     Aortic valve disorder
#  113       10006   142345        8      4240     Mitral valve disorder
#  123       10006   142345       10     03819  Staphylcocc septicem NEC
#  124       10006   142345       11      7850           Tachycardia NOS
#  127       10006   142345       12     E8791  Abn react-renal dialysis
#  128       10006   142345       13      V090    Inf mcrg rstn pncllins
#  131       10006   142345       14     56211   Dvrtcli colon w/o hmrhg
#  133       10006   142345       15     28529  Anemia-other chronic dis
#  138       10006   142345       16     25000  DMII wo cmp nt st uncntr
#  169       10006   142345       17     V5867  Long-term use of insulin
#  177       10006   142345       18     E9342    Adv eff anticoagulants
#  179       10006   142345       19     41401  Crnry athrscl natve vssl
#  197       10006   142345       20      2749                  Gout NOS
#  203       10006   142345       21      3051      Tobacco use disorder)

# %%
g.count()
# Out:
#             hadm_id  seq_num  icd9_code  short_title
# subject_id
# 10006            19       19         19           19
# 10011             6        6          6            6
# 10013             8        8          8            8
# 10017            14       14         14           14
# 10019            12       12         12           12
# ...             ...      ...        ...          ...
# 44083            14       14         14           14
# 44154             8        8          8            8
# 44212            23       23         23           23
# 44222            11       11         11           11
# 44228            11       11         11           11
#
# [100 rows x 4 columns]

# %%
for p_id, df in g:
  print("Patient ID: ", p_id)
  print(f'\t{ df.short_title.values }')
  print('-'*100)
# Out:
# <ipython-input-122-5030ac146c2d>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for p_id, df in g:
# Patient ID:  10006
# 	['Sepsis' 'React-oth vasc dev/graft' 'Hyp kid NOS w cr kid V'
#  'Atrial fibrillation' 'CHF NOS' 'Aortic valve disorder'
#  'Mitral valve disorder' 'Staphylcocc septicem NEC' 'Tachycardia NOS'
#  'Abn react-renal dialysis' 'Inf mcrg rstn pncllins'
#  'Dvrtcli colon w/o hmrhg' 'Anemia-other chronic dis'
#  'DMII wo cmp nt st uncntr' 'Long-term use of insulin'
#  'Adv eff anticoagulants' 'Crnry athrscl natve vssl' 'Gout NOS'
#  'Tobacco use disorder']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10011
# 	['Acute necrosis of liver' 'Hpt B acte wo cm wo dlta'
#  'Chrnc hpt C wo hpat coma' 'Opioid dependence-contin'
#  'Thrombocytopenia NOS' 'Hyperosmolality']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10013
# 	['Atrial fibrillation' 'Mitral valve disorder' 'Septicemia NOS'
#  'Subendo infarct, initial' 'Cardiogenic shock' 'Pneumonia, organism NOS'
#  'Oth lymp unsp xtrndl org' 'Hyperlipidemia NEC/NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10017
# 	['DMII wo cmp nt st uncntr' 'Pneumonia, organism NOS'
#  'Hyperlipidemia NEC/NOS' 'Fx surg nck humerus-clos' 'Emphysema NEC'
#  'Fx facial bone NEC-close' 'Fx malar/maxillary-close'
#  'Hematoma complic proc' 'Iatrogen pulm emb/infarc'
#  'Ac posthemorrhag anemia' 'Fall from slipping NEC'
#  'Abn react-surg proc NEC' 'Hx-circulatory dis NEC' 'Hypertension NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10019
# 	['Septicemia NOS' 'Hypertension NOS' 'Acute respiratry failure'
#  'Acute pancreatitis' 'Alcoh dep NEC/NOS-unspec' 'Blood in stool'
#  'Ac kidny fail, tubr necr' 'Hepatic encephalopathy'
#  'Shock w/o trauma NEC' 'Severe sepsis' 'Ac alcoholic hepatitis'
#  'Asthma NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10026
# 	['Intracerebral hemorrhage' 'Malignant hypertension'
#  'Urin tract infection NOS' 'Hyposmolality' 'Hx of breast malignancy'
#  'Idio periph neurpthy NOS' 'Anemia NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10027
# 	['Atrial fibrillation' 'CHF NOS' 'Mitral valve disorder'
#  'DMII wo cmp nt st uncntr' 'Crnry athrscl natve vssl' 'Hypertension NOS'
#  'Tricuspid valve disease' 'Other heart block' 'Chronic kidney dis NOS'
#  'Mental disor NEC oth dis' 'Rectal prolapse' 'Abnrml coagultion prfile']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10029
# 	['Hyp kid NOS w cr kid V' 'Atrial fibrillation' 'CHF NOS'
#  'Thrombocytopenia NOS' 'Severe sepsis' 'Urin tract infection NOS'
#  'Streptococcal septicemia' 'Comp-ren dialys dev/grft' 'Cholangitis'
#  'Choledochlith NOS w obst' 'End stage renal disease' 'Septic shock'
#  'Other pulmonary insuff' 'Pleural effusion NOS'
#  'Malfunc oth device/graft' 'Cerv spondyl w myelopath'
#  'Personal history of fall' 'Unc behav neo bone' 'Delirium d/t other cond'
#  'Status autm crd dfbrltr' 'Hx-prostatic malignancy']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10032
# 	['CHF NOS' 'Thrombocytopenia NOS' 'Ac posthemorrhag anemia'
#  'Fx lower humerus NEC-cl' 'Secondary malig neo bone'
#  'Food/vomit pneumonitis' 'Diastolc hrt failure NOS'
#  'Acute kidney failure NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10033
# 	['Atrial fibrillation' 'DMII wo cmp nt st uncntr' 'Hypertension NOS'
#  'Acute kidney failure NOS' 'Tox multnod goit no cris'
#  'Trachea & bronch dis NEC' 'Hyperpotassemia' 'Fall NOS'
#  'Pure hypercholesterolem' 'Depressive disorder NEC'
#  'Late eff CV dis-aphasia' 'Peptic ulcer NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10035
# 	['Gout NOS' 'Ocl crtd art wo infrct' 'Old myocardial infarct']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10036
# 	['Hyperosmolality' 'Septicemia NOS' 'Severe sepsis' 'Septic shock'
#  'Food/vomit pneumonitis' 'Acute kidney failure NOS' 'Acidosis'
#  'Esophageal reflux' "Alzheimer's disease" 'Dementia w/o behav dist'
#  'Polymyalgia rheumatica' 'Hypothyroidism NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10038
# 	['Sepsis' 'Atrial fibrillation' 'CHF NOS' 'Thrombocytopenia NOS'
#  'Hypertension NOS' 'Mental disor NEC oth dis' 'Abnrml coagultion prfile'
#  'Streptococcal septicemia' 'Diastolc hrt failure NOS'
#  'Acute kidney failure NOS' 'React-oth int ortho dev'
#  'Pyogen arthritis-pelvis' 'Alkalosis' 'Comp-internal joint pros'
#  'Failure to thrive-adult' 'Venous insufficiency NOS'
#  'Abn react-artif implant' 'Accident in place NEC' 'Osteoporosis NOS'
#  'Streptococcus group b']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10040
# 	['CHF NOS' 'Aortic valve disorder' 'Crnry athrscl natve vssl'
#  'Emphysema NEC' 'Acute respiratry failure' 'Esophageal reflux'
#  'Hyp ht dis NOS w ht fail' 'Bacteremia' 'Iron defic anemia NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10042
# 	['Atrial fibrillation' 'CHF NOS' 'Mitral valve disorder'
#  'Crnry athrscl natve vssl' 'Subendo infarct, initial' 'Surg compl-heart'
#  'Parox ventric tachycard' 'Prim pulm hypertension'
#  'Periph vascular dis NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10043
# 	['CHF NOS' 'Anemia-other chronic dis' 'Thrombocytopenia NOS'
#  'Pneumonia, organism NOS' 'Acute respiratry failure'
#  'Obs chr bronc w(ac) exac' 'Int inf clstrdium dfcile'
#  'Ac diastolic hrt failure']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10044
# 	['Atrial fibrillation' 'Crnry athrscl natve vssl' 'Hypertension NOS'
#  'Sec mal neo brain/spine' 'Cellulitis of leg' 'Second malig neo liver'
#  'Secondary malig neo lung' 'Renal & ureteral dis NOS'
#  'Anemia in neoplastic dis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10045
# 	['Atrial fibrillation' 'CHF NOS' 'DMII wo cmp nt st uncntr'
#  'Crnry athrscl natve vssl' 'Hyperlipidemia NEC/NOS' 'Hypertension NOS'
#  'Severe sepsis' 'Intracerebral hemorrhage' 'Urin tract infection NOS'
#  'Hyposmolality' 'Anemia NOS' 'Septic shock' 'Acute kidney failure NOS'
#  'Hypothyroidism NOS' 'Int inf clstrdium dfcile' 'Anaerobic septicemia'
#  'Lower extremity embolism' 'Acq coagul factor defic'
#  'Colstmy/enteros comp NEC' 'Stricture of artery'
#  'Subendo infarct, subseq' 'Mycoses NEC & NOS' 'Urinostomy status NEC'
#  'Hx-uterus malignancy NEC' 'Hx of irradiation' 'History of tobacco use'
#  'Status-post ptca']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10046
# 	['Sec mal neo brain/spine' 'Hx-uterus malignancy NEC' 'Convulsions NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10056
# 	['CHF NOS' 'Septicemia NOS' 'Ac kidny fail, tubr necr' 'Severe sepsis'
#  'Urin tract infection NOS' 'Hyposmolality' 'Septic shock'
#  'Ac diastolic hrt failure']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10059
# 	['Thrombocytopenia NOS' 'Septicemia NOS' 'Hypertension NOS'
#  'Acute respiratry failure' 'Severe sepsis' 'Chronic kidney dis NOS'
#  'Septic shock' 'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Cirrhosis of liver NOS' 'Cirrhosis of liver NOS'
#  'Portal vein thrombosis' 'Hpt C w/o hepat coma NOS'
#  'Hpt C w/o hepat coma NOS' 'Chr blood loss anemia'
#  'Chr blood loss anemia' 'Bleed esoph var oth dis'
#  'Bleed esoph var oth dis' 'Hepatorenal syndrome' 'Portal hypertension'
#  'Portal hypertension']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10061
# 	['CHF NOS' 'Acute necrosis of liver' 'Septicemia NOS'
#  'Subendo infarct, initial' 'Cardiogenic shock' 'Acute respiratry failure'
#  'Shock w/o trauma NEC' 'Acute kidney failure NOS' 'Pneumonia e coli']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10064
# 	['Atrial fibrillation' 'Cl skl base fx-deep coma'
#  'Traum hemothorax-closed' 'W/crft fall NEC-pers NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10065
# 	['Gout NOS' 'Hypertension NOS' 'Chronic kidney dis NOS'
#  'Pure hypercholesterolem' 'Esophageal reflux' 'Osteoporosis NOS'
#  'Mal neo stomach cardia' 'Sec mal neo GI NEC' 'Vasc comp med care NEC'
#  'Mal neo lymph intra-abd' 'Rheumatoid arthritis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10067
# 	['Ac posthemorrhag anemia' 'Liver laceration, major'
#  'Concussion-deep coma' 'Traumatic shock' 'Cardiac arrest'
#  'Oth coll stnd obj-mocycl' 'GI injury NEC-closed'
#  'Oth acq limb deformity']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10069
# 	['CHF NOS' 'DMII wo cmp nt st uncntr' 'Acute respiratry failure'
#  'Food/vomit pneumonitis' 'Acidosis' 'Epilepsy NOS w intr epil' 'Coma'
#  'Intellect disability NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10074
# 	['Atrial fibrillation' 'Pneumonia, organism NOS' 'Ac posthemorrhag anemia'
#  'Tricuspid valve disease' 'Acute kidney failure NOS'
#  'Angio intes w hmrhg' 'Rheumatic heart failure'
#  'Mitral insuf/aort stenos' 'Chr airway obstruct NEC'
#  'Cardiac dysrhythmias NEC' 'Long-term use anticoagul']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10076
# 	['Septicemia NOS' 'Pneumonia, organism NOS' 'Acute respiratry failure'
#  'Severe sepsis' 'Hyposmolality' 'Secondary malig neo bone'
#  'Acute kidney failure NOS' 'Acidosis' 'Secondary malig neo lung'
#  'Anemia in neoplastic dis' 'Second malig neo pleura'
#  'Mal neo lower lobe lung' 'Protein-cal malnutr NOS' 'Diarrhea'
#  'Adv eff antineoplastic']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10083
# 	['React-oth vasc dev/graft' 'CHF NOS' 'Anemia-other chronic dis'
#  'Urin tract infection NOS' 'Hyposmolality' 'Depressive disorder NEC'
#  'Acidosis' 'Esophageal reflux' 'Bacteremia' 'Amyloidosis NEC'
#  'Nutritional marasmus' 'Nephrotic syn in oth dis' 'Hypovolemia'
#  'Hematemesis' 'Inf mcr rst ot drg nt ml' 'Dis plas protein met NOS'
#  'Iatrogenc hypotnsion NEC' 'Dis plas protein met NEC'
#  'Enterococcus group d' 'Other esophagitis' 'Bacteroides fragilis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10088
# 	['Sepsis' 'CHF NOS' 'CHF NOS' 'CHF NOS' 'Inf mcrg rstn pncllins'
#  'Inf mcrg rstn pncllins' 'Anemia-other chronic dis' 'Hyperosmolality'
#  'Septicemia NOS' 'Septicemia NOS' 'Subendo infarct, initial'
#  'Oth lymp unsp xtrndl org' 'Hyperlipidemia NEC/NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Acute respiratry failure' 'Blood in stool'
#  'Severe sepsis' 'Urin tract infection NOS' 'Urin tract infection NOS'
#  'Anemia NOS' 'Septic shock' 'Septic shock' 'Other pulmonary insuff'
#  'Food/vomit pneumonitis' 'Acute kidney failure NOS'
#  'Depressive disorder NEC' 'Depressive disorder NEC' 'Acidosis'
#  'Periph vascular dis NOS' 'Periph vascular dis NOS' 'Status-post ptca'
#  'Status-post ptca' 'Status-post ptca' 'Cardiac dysrhythmias NEC'
#  'Paralysis agitans' 'Paralysis agitans' 'Vasc dementia w delirium'
#  'Cerebral atherosclerosis' 'Cerebral atherosclerosis'
#  'Gastrostomy status' 'Cor ath unsp vsl ntv/gft'
#  'Cor ath unsp vsl ntv/gft' 'Aortocoronary bypass' 'Aortocoronary bypass'
#  'Aortocoronary bypass' 'Hx-lymphatic malign NEC' 'Prsnl hst tuberculosis'
#  'Prsnl hst tuberculosis' 'Prsnl hst tuberculosis' 'Bronchitis NOS'
#  'Mth sus Stph aur els/NOS' 'Vascular dementia,uncomp'
#  'Ath ext autologs bps gft' 'Dvrtclo colon w/o hmrhg']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10089
# 	['Hypertension NOS' 'Intracerebral hemorrhage' 'Food/vomit pneumonitis'
#  'Cor ath unsp vsl ntv/gft' 'Aortocoronary bypass']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10090
# 	['Ac posthemorrhag anemia' 'Poison-antipsychotic NEC'
#  'Recur depr psych-severe' 'Pois-cns muscle depress'
#  'Pois-benzodiazepine tran' 'Poison-psychotropic agt'
#  'Poison-drug/medicin NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10093
# 	['Aortic valve disorder' 'Crnry athrscl natve vssl'
#  'Subendo infarct, initial' 'Hypertension NOS' 'Shock w/o trauma NEC'
#  'Acute kidney failure NOS' 'Periph vascular dis NOS'
#  'Protein-cal malnutr NOS' 'Gastrointest hemorr NOS' 'Dehydration']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10094
# 	['CHF NOS' 'CHF NOS' 'DMII wo cmp nt st uncntr' 'DMII wo cmp nt st uncntr'
#  'Hyperosmolality' 'Hyperosmolality' 'Septicemia NOS'
#  'Pneumonia, organism NOS' 'Severe sepsis' 'Tricuspid valve disease'
#  'Mental disor NEC oth dis' 'Food/vomit pneumonitis'
#  'Acute kidney failure NOS' 'Hypothyroidism NOS' 'Hypothyroidism NOS'
#  'Int inf clstrdium dfcile' 'Benign neo pituitary' 'Panhypopituitarism'
#  'Pressure ulcer, ankle']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10098
# 	['Parox ventric tachycard' 'Opn skl fx NEC-deep coma'
#  'Mv collision NOS-driver' 'Accid on street/highway'
#  'Open wound of face NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10101
# 	['Second malig neo liver' 'Secondary malig neo lung'
#  'Mal neo bronch/lung NEC' 'Second malig neo adrenal'
#  'Second malig neo kidney' 'Sec mal neo peritoneum'
#  'Secondary malig neo NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10102
# 	['Tachycardia NOS' 'Hyposmolality' 'Abnrml coagultion prfile'
#  'Pleural effusion NOS' 'Acidosis' 'Int inf clstrdium dfcile'
#  'Chr blood loss anemia' 'Gastrointest hemorr NOS'
#  'Ch myl leuk wo achv rmsn' 'Pulmonary collapse'
#  'Pressure ulcer, low back' 'Spleen disease NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10104
# 	['Hypertension NOS' 'Asthma NOS' 'Urin tract infection NOS'
#  'Hyposmolality' 'Pure hypercholesterolem' 'Osteoporosis NOS'
#  'Convulsions NEC' 'Adrenal hypofunction NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10106
# 	['DMII wo cmp nt st uncntr' 'Hypertension NOS' 'Alcoh dep NEC/NOS-unspec'
#  'Asthma NOS' 'Herpetic encephalitis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10111
# 	['Atrial fibrillation' 'CHF NOS' 'Aortic valve disorder'
#  'DMII wo cmp nt st uncntr' 'Acute respiratry failure'
#  'Acute kidney failure NOS' 'Chr airway obstruct NEC'
#  'Sinoatrial node dysfunct' 'Sleep apnea NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10112
# 	['Acute respiratry failure' 'Esophageal reflux' 'Hypothyroidism NOS'
#  'Paralysis agitans' 'Dvrtclo colon w/o hmrhg' 'Ventricular fibrillation'
#  'Anoxic brain damage' 'Persistent vegtv state' 'Bipolor I current NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10114
# 	['CHF NOS' 'Mitral valve disorder' 'DMII wo cmp nt st uncntr'
#  'Emphysema NEC' 'Anemia NOS' 'Renal & ureteral dis NOS'
#  'Intermed coronary synd' 'Drug-induced delirium'
#  'Adv eff benzodiaz tranq']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10117
# 	['React-oth vasc dev/graft' 'Thrombocytopenia NOS'
#  'Pneumonia, organism NOS' 'Acute respiratry failure' 'Acidosis'
#  'Bacteremia' 'Bacteremia' 'Mult mye w/o achv rmson'
#  'Mult mye w/o achv rmson' 'Thrush' 'Trnspl status-bne marrow' 'Glossitis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10119
# 	['Atrial fibrillation' 'Atrial fibrillation' 'Hypertension NOS'
#  'Hypertension NOS' 'Acute pancreatitis' 'Acute kidney failure NOS'
#  'Old myocardial infarct' 'Bacteremia' 'Long-term use anticoagul'
#  'Acute cholecystitis' 'Perforation gallbladder' 'Toxic encephalopathy'
#  'Chr duoden ulcer w hem' 'Chr stomach ulc w hem']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10120
# 	['Acute necrosis of liver' 'Septicemia NOS' 'Hx-circulatory dis NEC'
#  'Acute respiratry failure' 'Severe sepsis' 'Acute kidney failure NOS'
#  'Acidosis' 'Grand mal status' 'Defibrination syndrome' 'Cerebral edema'
#  'Metabolic encephalopathy' 'Encountr palliative care'
#  'Adv eff hydantoin deriv']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10124
# 	['Sepsis' 'Hyp kid NOS w cr kid V' 'Atrial fibrillation'
#  'Atrial fibrillation' 'CHF NOS' 'DMII wo cmp nt st uncntr'
#  'Pneumonia, organism NOS' 'Ac posthemorrhag anemia'
#  'Fall from slipping NEC' 'Abn react-surg proc NEC'
#  'Ac kidny fail, tubr necr' 'Urin tract infection NOS'
#  'Urin tract infection NOS' 'Chronic kidney dis NOS'
#  'Acute kidney failure NOS' 'Hyperpotassemia' 'Hypothyroidism NOS'
#  'Osteoporosis NOS' 'Acute & chronc resp fail' 'Ac on chr diast hrt fail'
#  'DMII unspf uncntrld' 'Meth susc Staph aur sept'
#  'Pressure ulcer, buttock' 'Chr pulmon heart dis NEC'
#  'Obstructive sleep apnea' 'Obesity NOS' 'Aftrcre traumatic fx hip'
#  'Hx-ven thrombosis/embols' 'Constipation NOS' 'Intertrochanteric fx-cl'
#  'Chr diastolic hrt fail' 'Hemorrhage complic proc'
#  'Abdom aortic aneurysm' 'Hy kid NOS w cr kid I-IV']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10126
# 	['CHF NOS' 'Acute necrosis of liver' 'Ac kidny fail, tubr necr'
#  'Acq coagul factor defic' 'Spleen disease NEC' 'Acute cholecystitis'
#  'Chr pulmon heart dis NEC' 'Compl liver transplant'
#  'Alcohol cirrhosis liver' 'Hpt B chrn wo cm wo dlta'
#  'Iatrogenic pneumothorax' 'Hemoperitoneum' 'Obstruction of bile duct']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10127
# 	['Pneumonia, organism NOS' 'Cardiac dysrhythmias NEC'
#  'C1-c4 fx-cl/com cord les' 'Fx femur shaft-closed'
#  'Cl skul base fx-brf coma' 'Seroma complicting proc'
#  'Quadrplg c1-c4, complete' 'Oth coll stndng obj-psgr'
#  'Vascular myelopathies' 'Open wound of scalp' 'Nasal bone fx-closed'
#  'Candidias urogenital NEC' 'Nystagmus NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10130
# 	['DMII wo cmp nt st uncntr' 'Septicemia NOS' 'Hyposmolality'
#  'Second malig neo liver' 'Nutritional marasmus' 'Sec mal neo peritoneum'
#  'Intestinal fistula' 'Hx of colonic malignancy']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  10132
# 	['Sepsis' 'Septicemia NOS' 'Subendo infarct, initial'
#  'Sec mal neo brain/spine' 'Hx-uterus malignancy NEC'
#  'Iatrogenic pneumothorax' 'Candidiasis of lung' 'Pulm embol/infarct NEC'
#  'Malig neo main bronchus']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40124
# 	['Pneumonia, organism NOS' 'Pneumonia, organism NOS' 'Hypertension NOS'
#  'Acute respiratry failure' 'Anemia NOS' 'Anemia NOS'
#  'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Chr airway obstruct NEC' 'Chr airway obstruct NEC' 'Dehydration'
#  'Mal neo bronch/lung NEC' 'Mal neo bronch/lung NEC'
#  'Nonspecif skin erupt NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40177
# 	['Acute necrosis of liver' 'Septicemia NOS' 'Subendo infarct, initial'
#  'Hyperlipidemia NEC/NOS' 'Ac posthemorrhag anemia' 'Hypertension NOS'
#  'Acute pancreatitis' 'Severe sepsis' 'Cholangitis' 'Pleural effusion NOS'
#  'Acute kidney failure NOS' 'Hyperpotassemia' 'Acidosis'
#  'Cor ath unsp vsl ntv/gft' 'Aortocoronary bypass' 'Dehydration'
#  'Pulmonary collapse' 'Gall&bil cal w/oth w obs' 'Glaucoma NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40204
# 	['Hyp kid NOS w cr kid V' 'CHF NOS' 'DMII wo cmp nt st uncntr'
#  'Crnry athrscl natve vssl' 'Pneumonia, organism NOS'
#  'Urin tract infection NOS' 'End stage renal disease'
#  'Chr airway obstruct NEC' 'Chr systolic hrt failure'
#  'Sec hyperparathyrd-renal' 'Other alter consciousnes'
#  'Renal dialysis status' 'Joint pain-l/leg' 'Meth resis Staph carrier']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40277
# 	['Hypertension NOS' 'Hyposmolality' 'Fall NOS' 'Chr airway obstruct NEC'
#  'Subarach hem-coma NOS' 'Brain hem NEC-coma NOS' 'Hypopotassemia'
#  'Stridor' 'Anxiety state NOS' 'Personal history UTI']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40286
# 	['Atrial fibrillation' 'Ac posthemorrhag anemia' 'Hypertension NOS'
#  'Delirium d/t other cond' 'Hypothyroidism NOS' 'Iatrogenc hypotnsion NEC'
#  'Hypopotassemia' 'Traum arthropathy-pelvis' 'Adv eff opiates' 'Apnea']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40304
# 	['Atrial fibrillation' 'CHF NOS' 'Aortic valve disorder' 'Gout NOS'
#  'Hyperosmolality' 'Pneumonia, organism NOS' 'Oth lymp unsp xtrndl org'
#  'Chronic kidney dis NOS' 'Acute kidney failure NOS'
#  'Periph vascular dis NOS' 'Long-term use anticoagul' 'Pulmonary collapse'
#  'Ac on chr diast hrt fail' 'Obstructive sleep apnea'
#  'Mal neo lymph-intrathor' 'Foreign body bronchus'
#  'Anemia in chr kidney dis' 'Hx-bronchogenic malignan']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40310
# 	['Tachycardia NOS' 'Oth lymp unsp xtrndl org' 'Acute respiratry failure'
#  'Acute respiratry failure' 'Ac kidny fail, tubr necr' 'Hyperpotassemia'
#  'Abn react-artif implant' 'Parox ventric tachycard'
#  'Adv eff antineoplastic' 'Iatrogenc hypotnsion NEC'
#  'Benign neo pituitary' 'Benign neo pituitary' 'Pulmonary collapse'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Hx-ven thrombosis/embols' 'Iatrogenic pneumothorax'
#  'Pressure ulcer, stage IV' 'Pressure ulcer, stage IV'
#  'Meth sus pneum d/t Staph' 'Brkt tmr unsp xtrndl org'
#  'Brkt tmr unsp xtrndl org' 'Acromegaly and gigantism'
#  'Acromegaly and gigantism' 'Hx antineoplastic chemo' 'Constipation NEC'
#  'Constipation NEC' 'Drug dermatitis NOS' 'Dis phosphorus metabol'
#  'Dis phosphorus metabol' 'Hiccough' 'Hx Methicln resist Staph'
#  'Adv eff antibiotics NEC' 'Tumor lysis syndrome'
#  'Meth res pneu d/t Staph' 'Aplastic anemias NEC'
#  'Pneu mycplsm pneumoniae' 'Ac DVT/emb prox low ext'
#  'Mixed acid-base bal dis' 'Ac embl suprfcl up ext'
#  'Crit illness neuropathy' 'Neutropenia NOS' 'Corneal ulcer NOS'
#  'Retention urine NOS' 'Bronchiectas w/o ac exac' "Bell's palsy"
#  'Hypercalcemia' 'Hydrocele NOS' 'Orchitis/epididymit NOS'
#  'Osteoarthrosis-mult site' 'Mucosits d/t antineo rx'
#  'Drug induced neutropenia' 'Lack of housing']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40456
# 	['CHF NOS' 'Mitral valve disorder' 'Crnry athrscl natve vssl' 'Anemia NOS'
#  'Cardiac dysrhythmias NEC' 'Long-term use anticoagul'
#  'Hx-ven thrombosis/embols' 'Ac on chr syst hrt fail'
#  'B12 defic anemia NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40503
# 	['Atrial fibrillation' 'CHF NOS' 'Mitral valve disorder'
#  'DMII wo cmp nt st uncntr' 'Crnry athrscl natve vssl'
#  'Subendo infarct, initial' 'Cardiogenic shock' 'Hypertension NOS'
#  'Hyposmolality' 'Polymyalgia rheumatica' 'Ac systolic hrt failure'
#  'Lumbosacral spondylosis' 'Pure hyperglyceridemia' 'Idiopathic scoliosis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40595
# 	['Atrial fibrillation' 'Mitral valve disorder' 'Acute respiratry failure'
#  'Hx of breast malignancy' 'Anemia NOS' 'Pleural effusion NOS'
#  'Malfunc oth device/graft' 'Trachea & bronch dis NEC'
#  'Abn react-artif implant' 'Int inf clstrdium dfcile' 'Hx of irradiation'
#  'Long-term use anticoagul' 'Pulmonary collapse'
#  'Meth resis Staph carrier' 'Hx antineoplastic chemo'
#  'Meth res pneu d/t Staph' 'Tracheoesophageal fstula'
#  'Mal neo bronch/lung NOS' 'Atrial flutter' 'Ventltr assoc pneumonia'
#  'Other dsrders esophagus' 'Benign hypertension' 'Dysphagia,pharyngoesoph'
#  'Abnormal glucose NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40601
# 	['Atrial fibrillation' 'CHF NOS' 'Crnry athrscl natve vssl'
#  'Cardiogenic shock' 'Hyperlipidemia NEC/NOS' 'Hypertension NOS'
#  'Asthma NOS' 'Urin tract infection NOS' 'Ac systolic hrt failure'
#  'AMI anterolateral, init' 'Morbid obesity']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40612
# 	['Sepsis' 'CHF NOS' 'Septicemia NOS' 'Mental disor NEC oth dis'
#  'Chr airway obstruct NEC' 'Acute cholecystitis' 'Paralytic ileus'
#  'Epilep NOS w/o intr epil' 'Subac dyskinesa d/t drug'
#  'Adv eff medicinal NOS' 'Schizoaffective dis NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40655
# 	['Sepsis' 'CHF NOS' 'Anemia-other chronic dis' 'Hyperlipidemia NEC/NOS'
#  'Acute kidney failure NOS' 'Venous insufficiency NOS' 'Cellulitis of leg'
#  'Cor ath unsp vsl ntv/gft' 'Aortocoronary bypass'
#  'Sinoatrial node dysfunct' 'Hy kid NOS w cr kid I-IV'
#  'Chr systolic hrt failure' 'Hypopotassemia' 'Septicemia NEC'
#  'Chr kidney dis stage IV' 'Gstr/ddnts NOS w hmrhg'
#  'Ulcer of heel & midfoot' 'DMII wo cmp uncntrld']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  40687
# 	['Hyperosmolality' 'Pneumonia, organism NOS' 'Hypertension NOS'
#  'Acute respiratry failure' 'Hx of breast malignancy'
#  'Secondary malig neo bone' 'Pure hypercholesterolem'
#  'Secondary malig neo lung' 'Second malig neo pleura'
#  'Adv eff antineoplastic' 'Sec mal neo peritoneum'
#  'Mal neo lymph-intrathor' 'Ac DVT/embl low ext NOS'
#  'Mal neo lymph-inguin/leg']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  41795
# 	['Atrial fibrillation' 'CHF NOS' 'CHF NOS' 'Mitral valve disorder'
#  'DMII wo cmp nt st uncntr' 'Long-term use of insulin'
#  'Long-term use of insulin' 'Adv eff anticoagulants'
#  'Tobacco use disorder' 'Thrombocytopenia NOS' 'Pneumonia, organism NOS'
#  'Hypertension NOS' 'Acute respiratry failure' 'Acute respiratry failure'
#  'Hyposmolality' 'Abnrml coagultion prfile' 'Acidosis'
#  'Venous insufficiency NOS' 'Venous insufficiency NOS'
#  'Obs chr bronc w(ac) exac' 'Obs chr bronc w(ac) exac'
#  'Long-term use anticoagul' 'Iatrogenc hypotnsion NEC'
#  'Aortocoronary bypass' 'Ac on chr diast hrt fail'
#  'Chr pulmon heart dis NEC' 'Obstructive sleep apnea'
#  'Obstructive sleep apnea' 'Chr diastolic hrt fail' 'Hypopotassemia'
#  'Morbid obesity' 'Morbid obesity' 'DMII wo cmp uncntrld'
#  'Schizophr dis resid-chr' 'Schizophr dis resid-chr' 'Ulcer of calf'
#  'Heart valve replac NEC' 'Heart valve replac NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  41914
# 	['DMII wo cmp nt st uncntr' 'Long-term use of insulin'
#  'Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Alcoh dep NEC/NOS-unspec'
#  'Severe sepsis' 'Anemia NOS' 'Pleural effusion NOS'
#  'Acute kidney failure NOS' 'History of tobacco use' 'Bronchitis NOS'
#  'Pulmonary collapse' 'Anoxic brain damage' 'Acute & chronc resp fail'
#  'Pressure ulcer, buttock' 'Compl liver transplant'
#  'Ventltr assoc pneumonia' 'Respirator depend status'
#  'Pseudomonas septicemia' 'Gram-neg septicemia NEC' 'Atten to gastrostomy'
#  'Pericardial disease NOS' 'Pressure ulcer, heel'
#  'Pressure ulcer,stage NOS' 'Pressure ulcer, stage II'
#  'Oth sequela, chr liv dis' 'Chronic sinusitis NOS'
#  'Atten to tracheostomy' 'Aftrce traum fx bone NEC'
#  'Aftrcare traum fx up arm' 'Late eff motor vehic acc']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  41976
# 	['Sepsis' 'Sepsis' 'Sepsis' 'Atrial fibrillation' 'Atrial fibrillation'
#  'Atrial fibrillation' 'Atrial fibrillation' 'Atrial fibrillation'
#  'Atrial fibrillation' 'Atrial fibrillation' 'Atrial fibrillation'
#  'Atrial fibrillation' 'Atrial fibrillation' 'Atrial fibrillation'
#  'Atrial fibrillation' 'DMII wo cmp nt st uncntr'
#  'DMII wo cmp nt st uncntr' 'Long-term use of insulin'
#  'Long-term use of insulin' 'Long-term use of insulin' 'Hyperosmolality'
#  'Hyperosmolality' 'Hyperosmolality' 'Hyperosmolality' 'Hyperosmolality'
#  'Hyperosmolality' 'Hyperosmolality' 'Septicemia NOS' 'Septicemia NOS'
#  'Septicemia NOS' 'Septicemia NOS' 'Septicemia NOS' 'Septicemia NOS'
#  'Septicemia NOS' 'Septicemia NOS' 'Pneumonia, organism NOS'
#  'Pneumonia, organism NOS' 'Hyperlipidemia NEC/NOS'
#  'Hyperlipidemia NEC/NOS' 'Hyperlipidemia NEC/NOS'
#  'Hyperlipidemia NEC/NOS' 'Hyperlipidemia NEC/NOS'
#  'Hyperlipidemia NEC/NOS' 'Hyperlipidemia NEC/NOS'
#  'Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Hypertension NOS' 'Acute respiratry failure'
#  'Acute respiratry failure' 'Acute respiratry failure' 'Severe sepsis'
#  'Severe sepsis' 'Severe sepsis' 'Severe sepsis' 'Severe sepsis'
#  'Severe sepsis' 'Severe sepsis' 'Severe sepsis' 'Severe sepsis'
#  'Urin tract infection NOS' 'Urin tract infection NOS'
#  'Urin tract infection NOS' 'Urin tract infection NOS'
#  'Urin tract infection NOS' 'Urin tract infection NOS'
#  'Urin tract infection NOS' 'Urin tract infection NOS'
#  'Urin tract infection NOS' 'Hyposmolality' 'Idio periph neurpthy NOS'
#  'Anemia NOS' 'Anemia NOS' 'Anemia NOS' 'Anemia NOS' 'Anemia NOS'
#  'Anemia NOS' 'Anemia NOS' 'Septic shock' 'Septic shock' 'Septic shock'
#  'Septic shock' 'Septic shock' 'Septic shock' 'Delirium d/t other cond'
#  'Food/vomit pneumonitis' 'Food/vomit pneumonitis'
#  'Food/vomit pneumonitis' 'Food/vomit pneumonitis'
#  'Food/vomit pneumonitis' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Hyperpotassemia' 'Depressive disorder NEC'
#  'Depressive disorder NEC' 'Depressive disorder NEC'
#  'Depressive disorder NEC' 'Depressive disorder NEC'
#  'Depressive disorder NEC' 'Depressive disorder NEC'
#  'Late eff CV dis-aphasia' 'Acidosis' 'Esophageal reflux'
#  'Esophageal reflux' 'Esophageal reflux' 'Esophageal reflux'
#  'Hypothyroidism NOS' 'Hypothyroidism NOS' 'Hypothyroidism NOS'
#  'Hypothyroidism NOS' 'Hypothyroidism NOS' 'Hypothyroidism NOS'
#  'Hypothyroidism NOS' 'Hypothyroidism NOS' 'Hypothyroidism NOS'
#  'Hypothyroidism NOS' 'Hypothyroidism NOS' 'Hypothyroidism NOS'
#  'Hypothyroidism NOS' 'Alkalosis' 'Periph vascular dis NOS'
#  'Periph vascular dis NOS' 'Periph vascular dis NOS'
#  'Int inf clstrdium dfcile' 'Anaerobic septicemia'
#  'History of tobacco use' 'History of tobacco use' 'Chr blood loss anemia'
#  'Long-term use anticoagul' 'Long-term use anticoagul'
#  'Long-term use anticoagul' 'Long-term use anticoagul'
#  'Long-term use anticoagul' 'Long-term use anticoagul'
#  'Long-term use anticoagul' 'Long-term use anticoagul'
#  'Long-term use anticoagul' 'Hematemesis' 'Other esophagitis'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Pressure ulcer, low back' 'Pressure ulcer, low back'
#  'Pressure ulcer, low back' 'Thrush' 'Pressure ulcer, buttock'
#  'Hx-ven thrombosis/embols' 'Hx-ven thrombosis/embols'
#  'Hemorrhage complic proc' 'Personal history UTI'
#  'Pressure ulcer, stage IV' 'Hx Methicln resist Staph'
#  'Retention urine NOS' 'Gram-neg septicemia NEC' 'Gram-neg septicemia NEC'
#  'Pressure ulcer,stage NOS' 'Pressure ulcer,stage NOS'
#  'Pressure ulcer,stage NOS' 'Pressure ulcer, stage II'
#  'Pressure ulcer, stage II' 'Pressure ulcer, stage II'
#  'Pressure ulcer, stage II' 'DMII neuro nt st uncntrl'
#  'DMII neuro nt st uncntrl' 'DMII neuro nt st uncntrl'
#  'DMII neuro nt st uncntrl' 'DMII neuro nt st uncntrl'
#  'DMII neuro nt st uncntrl' 'DMII neuro nt st uncntrl'
#  'DMII neuro nt st uncntrl' 'DMII neuro nt st uncntrl'
#  'DMII neuro nt st uncntrl' 'DMII neuro nt st uncntrl'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Neuropathy in diabetes' 'Neuropathy in diabetes'
#  'Hx TIA/stroke w/o resid' 'Hx TIA/stroke w/o resid' 'Tracheostomy status'
#  'Tracheostomy status' 'Tracheostomy status' 'Tracheostomy status'
#  'Tracheostomy status' 'Tracheostomy status' 'Tracheostomy status'
#  'Tracheostomy status' 'Tracheostomy status' 'Pressure ulcer, stage I'
#  'Hematuria NOS' 'Urethral stricture NOS' 'Gastrostomy comp - mech'
#  'Paraplegia NOS' 'Paraplegia NOS' 'Tracheostomy comp NEC'
#  'Abn react-procedure NEC' 'Lt ef oth parals-bilat'
#  'Lt ef oth parals-bilat' 'Lt ef oth parals-bilat'
#  'Late ef-spch/lng def NOS' 'Late ef-spch/lng def NOS'
#  'Bed confinement status' 'Pressure ulcer,stage III'
#  'Pressure ulcer,stage III' 'Abn involun movement NEC'
#  'Enterostomy status NEC' 'Ileostomy status' 'Ileostomy status'
#  'Ileostomy status' 'DMII neuro uncntrld' 'Pseudomonas infect NOS'
#  'Pneumo oth grm-neg bact' 'Pneumo oth grm-neg bact'
#  'Quadriplegia, unspecifd' 'Dis magnesium metabolism'
#  'Gastrostomy comp NEC' 'Gastrostomy comp NEC' 'Urinary obstruction NOS'
#  'Leukocytosis NOS' 'Vitamin D deficiency NOS' 'Chronic pain NEC'
#  'Do not resusctate status' 'Acquire absnce intestine'
#  'Late ef-spch/lang df NEC' 'Late ef-spch/lang df NEC' 'MRSA septicemia'
#  'React-indwell urin cath' 'React-indwell urin cath'
#  'Gram-neg septicemia NOS' 'Late ef CV dis dysphagia' 'Dysphagia NOS'
#  'Late effect CV dis NEC' 'Proteus infection NOS' 'Abn react-urinary cath']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  41983
# 	['Mitral valve disorder' 'Hypertension NOS' 'Urin tract infection NOS'
#  'Hyposmolality' 'Mental disor NEC oth dis' 'Esophageal reflux'
#  'Hypothyroidism NOS' 'Encountr palliative care' 'Fx c1 vertebra-closed'
#  'Fx dorsal vertebra-close' 'Ch lym leuk wo achv rmsn'
#  'Fx c2 vertebra-closed' 'Open wnd knee/leg-compl'
#  'Fall on stair/step NEC' 'Accident in home' 'Cataract NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42033
# 	['Atrial fibrillation' 'CHF NOS' 'Crnry athrscl natve vssl'
#  'Surg compl-heart' 'Prim pulm hypertension' 'Mitral insuf/aort stenos'
#  'Ac systolic hrt failure']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42066
# 	['Gout NOS' 'Food/vomit pneumonitis' 'Trachea & bronch dis NEC'
#  'Cardiac arrest' 'Intellect disability NOS' 'Gastrostomy status'
#  'Epilep NOS w/o intr epil' 'Respirator depend status' 'Dysphagia NOS'
#  "Down's syndrome"]
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42075
# 	['DMII wo cmp nt st uncntr' 'Crnry athrscl natve vssl'
#  'Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Acute respiratry failure'
#  'Secondary malig neo bone' 'Food/vomit pneumonitis'
#  'Acute kidney failure NOS' 'Acidosis' 'Second malig neo liver'
#  'Cardiac arrest' 'Chr airway obstruct NEC' 'Gastrointest hemorr NOS'
#  'AMI inferior wall, init' 'Mal neo upper lobe lung' 'Hypotension NEC'
#  'Heparin-indu thrombocyto']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42135
# 	['Pneumonia, organism NOS' 'Acute respiratry failure'
#  'Hepatic encephalopathy' 'Hepatic encephalopathy' 'Severe sepsis'
#  'Chronic kidney dis NOS' 'Septic shock' 'Acute kidney failure NOS'
#  'Acute kidney failure NOS' 'Acidosis' 'Acidosis' 'Alkalosis'
#  'Convulsions NEC' 'Portal vein thrombosis' 'Hepatorenal syndrome'
#  'Protein-cal malnutr NOS' 'Nutritional marasmus'
#  'Gastrointest hemorr NOS' 'Alcohol cirrhosis liver'
#  'Alcohol cirrhosis liver' 'Candidias urogenital NEC'
#  'Meth resis Staph carrier' 'Hypopotassemia' 'Hematuria NOS'
#  'MRSA septicemia' 'Ascites NEC' 'Gastroduodenal dis NEC'
#  'Gastroduodenal dis NEC' 'Alcoh dep NEC/NOS-remiss'
#  'Await organ transplnt st' 'Esoph varice oth dis NOS' 'Cachexia'
#  'Hx of past noncompliance' 'Alcoh dep NEC/NOS-contin']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42199
# 	['DMII wo cmp nt st uncntr' 'Subendo infarct, initial'
#  'Hematoma complic proc' 'Hypertension NOS' 'Hx of breast malignancy'
#  'Anemia NOS' 'Bacteremia' 'Second malig neo liver'
#  'Secondary malig neo lung' 'Hx-ven thrombosis/embols'
#  'Abn react-procedure NEC' 'Crbl thrmbs w infrct'
#  'Unsp hemiplga unspf side' 'Mal neo pancreas head'
#  'Thrombophlebitis migrans']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42231
# 	['Atrial fibrillation' 'Hyperlipidemia NEC/NOS' 'Hypertension NOS'
#  'Hx of breast malignancy' 'Anemia NOS' 'Pleural effusion NOS'
#  'Delirium d/t other cond' 'Cardiac dysrhythmias NEC'
#  'Iatrogenc hypotnsion NEC' 'Malig neopl kidney' 'Mal neo lymph-intrapelv'
#  'Accidental op laceration' 'Acc cut/hem in surgery']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42275
# 	['Obs chr bronc w(ac) exac' 'Hx of irradiation' 'History of tobacco use'
#  'Obstructive sleep apnea' 'Hy kid NOS w cr kid I-IV'
#  'Mal neo lymph-intrathor' 'Hx antineoplastic chemo'
#  'Mal neo bronch/lung NOS' 'Malign neopl thyroid'
#  'Chr kidney dis stage III' 'Dysphagia, oropharyngeal'
#  'Esophageal stricture' 'Status cardiac pacemaker'
#  'BPH w/o urinary obs/LUTS' 'Vocal paral bilat part'
#  'Depend-supplement oxygen']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42281
# 	['Hyperosmolality' 'Ac posthemorrhag anemia' 'Acute respiratry failure'
#  'Acute kidney failure NOS' 'Peptic ulcer NOS' 'Acidosis'
#  'Hx of irradiation' 'Cirrhosis of liver NOS' 'Bleed esoph var oth dis'
#  'Portal hypertension' 'Ventricular fibrillation' 'Hypopotassemia'
#  'Ascites NEC' 'Digest-genit fistul, fem' 'Irradiation cystitis'
#  'Chrnc hpt C w hepat Coma' 'Irritable bowel syndrome'
#  'Rectal & anal dis NEC' 'Diaphragmatic hernia' 'Hx-cervical malignancy'
#  'Acq absnce cervix/uterus' 'Abn react-radiotherapy']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42292
# 	['Atrial fibrillation' 'Tobacco use disorder' 'Pneumonia, organism NOS'
#  'Anemia NOS' 'Esophageal reflux' 'Mv collision NOS-driver'
#  'Accid on street/highway' 'Other alter consciousnes'
#  'Abn react-urinary cath' 'Open wound of finger' 'Alcohol withdrawal'
#  'DMII oth nt st uncntrld' 'Ac alcohol intox-contin'
#  'Cornea transplant status' 'DMII circ nt st uncntrld'
#  'Athscl extrm ntv art NOS' 'Malfunc urethral cath'
#  'Accid in resident instit']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42302
# 	['CHF NOS' 'DMII wo cmp nt st uncntr' 'Crnry athrscl natve vssl'
#  'Chronic kidney dis NOS' 'Mental disor NEC oth dis'
#  'Delirium d/t other cond' 'Food/vomit pneumonitis'
#  'Depressive disorder NEC' 'Old myocardial infarct' 'Esophageal reflux'
#  'Osteoporosis NOS' 'Chr diastolic hrt fail' 'Hy kid NOS w cr kid I-IV'
#  'Personal history UTI' 'Anemia in chr kidney dis'
#  'Hx of past noncompliance' 'Ch obst asth w (ac) exac' 'Hypoxemia'
#  'Multiple sclerosis' 'Ectropion NOS' 'Psychosis NOS'
#  'Long-term use steroids' 'MRSA elsewhere/NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42321
# 	['Atrial fibrillation' 'Hyperosmolality' 'Ac posthemorrhag anemia'
#  'Urin tract infection NOS' 'Chronic kidney dis NOS'
#  'Delirium d/t other cond' 'Acute kidney failure NOS'
#  'Pure hypercholesterolem' 'Depressive disorder NEC' "Alzheimer's disease"
#  'Dementia w/o behav dist' 'Hy kid NOS w cr kid I-IV' 'Anxiety state NOS'
#  'Abn react-procedure NEC' 'Traum pneumothorax-close'
#  'Congen obst urtroplv jnc' 'Volume depletion NOS'
#  'Lt ef oth paral side NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42346
# 	['Atrial fibrillation' 'Atrial fibrillation' 'CHF NOS'
#  'DMII wo cmp nt st uncntr' 'DMII wo cmp nt st uncntr'
#  'Long-term use of insulin' 'Pneumonia, organism NOS'
#  'Pneumonia, organism NOS' 'Hyperlipidemia NEC/NOS'
#  'Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Acute respiratry failure' 'Urin tract infection NOS'
#  'Tricuspid valve disease' 'Tricuspid valve disease' 'Peptic ulcer NOS'
#  'Peptic ulcer NOS' 'Periph vascular dis NOS' 'Periph vascular dis NOS'
#  'Rheumatic heart failure' 'Long-term use anticoagul'
#  'Long-term use anticoagul' 'Encountr palliative care' 'Constipation NOS'
#  'Glaucoma NOS' 'Glaucoma NOS' 'Mixed acid-base bal dis'
#  'Ac systolic hrt failure' 'Status cardiac pacemaker'
#  'Status cardiac pacemaker' 'Hypoxemia' 'Volvulus of intestine'
#  'Mitral/aortic val insuff' 'Hypotension NOS' 'Hx-skin malignancy NEC'
#  'Hx-skin malignancy NEC' 'Prim cardiomyopathy NEC'
#  'Mitr/aortic mult involv' 'Conjunctivitis NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42367
# 	['CHF NOS' 'DMII wo cmp nt st uncntr' 'Hyposmolality' 'Anemia NOS'
#  'Mental disor NEC oth dis' 'Fall NOS' 'Depressive disorder NEC'
#  'Esophageal reflux' 'History of tobacco use' 'Chr diastolic hrt fail'
#  'Hypopotassemia' 'Late effect CV dis NEC' 'Subdural hem-deep coma'
#  'Norml pressure hydroceph' 'Epil par cont w/o int ep'
#  'Ventricular shunt status' 'Muscskel sympt limb NEC'
#  'Euthyroid sick syndrome' 'Fever NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42412
# 	['Atrial fibrillation' 'CHF NOS' 'Pneumonia, organism NOS'
#  'Hyperlipidemia NEC/NOS' 'Chronic kidney dis NOS'
#  'Mental disor NEC oth dis' 'Delirium d/t other cond'
#  'Acute kidney failure NOS' 'Cor ath unsp vsl ntv/gft'
#  'Aortocoronary bypass' 'Chr diastolic hrt fail'
#  'Hy kid NOS w cr kid I-IV' 'Anemia in chr kidney dis'
#  'Adv eff antibiotics NEC' 'BPH w/o urinary obs/LUTS'
#  'Oth spcf hypoglycemia' 'Bladder/urethra inj-clos' 'Gross hematuria'
#  'Chr ischemic hrt dis NOS' 'Prsnl hst colonic polyps' 'Accident NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42430
# 	['Atrial fibrillation' 'DMII wo cmp nt st uncntr' 'Tobacco use disorder'
#  'Hypertension NOS' 'Acute respiratry failure' 'Food/vomit pneumonitis'
#  'Periph vascular dis NOS' 'Chr airway obstruct NEC'
#  'Crbl emblsm w infrct' 'Compression of brain']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  42458
# 	['Mental disor NEC oth dis' 'Acute kidney failure NOS' 'Hypovolemia'
#  'Hypotension NEC' 'Parox atrial tachycardia' 'Spinal stenosis NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43735
# 	['Atrial fibrillation' 'CHF NOS' 'DMII wo cmp nt st uncntr'
#  'Crnry athrscl natve vssl' 'Pneumonia, organism NOS'
#  'Hyperlipidemia NEC/NOS' 'Chronic kidney dis NOS' 'Pleural effusion NOS'
#  'Acute kidney failure NOS' 'Hypothyroidism NOS' 'Parox ventric tachycard'
#  'Periph vascular dis NOS' 'Status-post ptca' 'Chr airway obstruct NEC'
#  'Gastrointest hemorr NOS' 'Obstructive sleep apnea'
#  'Hy kid NOS w cr kid I-IV' 'Alcohol cirrhosis liver' 'Ascites NEC'
#  'Hypoxemia' 'Prim cardiomyopathy NEC' 'Encephalopathy NOS'
#  'Ac/chr syst/dia hrt fail']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43746
# 	['Hypertension NOS' 'Urin tract infection NOS' 'Acute kidney failure NOS'
#  'Second malig neo liver' 'Chr blood loss anemia'
#  'Mal neo lymph intra-abd' 'Sec mal neo peritoneum' 'Retention urine NOS'
#  'Ascites NEC' 'Malignant neopl rectum' 'Pancreat cyst/pseudocyst'
#  'Bladder neck obstruction' 'Klebsiella pneumoniae'
#  'Osteoarthros NOS-unspec' 'Abdmnal pain unspcf site' 'Edema']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43748
# 	['CHF NOS' 'Thrombocytopenia NOS' 'Cardiogenic shock'
#  'Acute kidney failure NOS' 'Cellulitis of leg' 'Cor ath unsp vsl ntv/gft'
#  'Aortocoronary bypass' 'Ac/chr syst/dia hrt fail']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43779
# 	['DMII wo cmp nt st uncntr' 'Hyperlipidemia NEC/NOS'
#  'Fall from slipping NEC' 'Chronic kidney dis NOS'
#  'Acute kidney failure NOS' 'Secondary malig neo lung'
#  'Hy kid NOS w cr kid I-IV' 'Anemia in chr kidney dis'
#  'Subdural hem w/o coma' 'Malignant neo colon NOS'
#  'Rt bbb/lft ant fasc blk']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43798
# 	['Atrial fibrillation' 'DMII wo cmp nt st uncntr' 'Thrombocytopenia NOS'
#  'Acute respiratry failure' 'Hyposmolality' 'Chronic kidney dis NOS'
#  'Esophageal reflux' 'Alkalosis' 'Surg compl-heart'
#  'Mal neo stomach cardia' 'Hy kid NOS w cr kid I-IV' 'MRSA elsewhere/NOS'
#  'Effusion NEC exc tb' 'Vocal paral unilat part' 'Empyema w/o fistula']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43827
# 	['Atrial fibrillation' 'CHF NOS' 'Aortic valve disorder'
#  'Crnry athrscl natve vssl' 'Hypertension NOS' 'Hx of breast malignancy'
#  'Anemia NOS' 'Esophageal reflux' 'Prim pulm hypertension'
#  'Chr diastolic hrt fail' 'AMI inferior wall, init'
#  'Acq absnce cervix/uterus' 'Macular degeneration NOS'
#  'Acq absnce breast/nipple']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43870
# 	['Atrial fibrillation' 'DMII wo cmp nt st uncntr' 'Hyperlipidemia NEC/NOS'
#  'Hypertension NOS' 'Acute respiratry failure' 'Urin tract infection NOS'
#  'Anemia NOS' 'Unsp hemiplga unspf side' 'Crbl art ocl NOS w infrc'
#  'Pulm congest/hypostasis']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43879
# 	['Acute respiratry failure' 'Hx of breast malignancy'
#  'Pleural effusion NOS' 'Depressive disorder NEC' 'Acidosis'
#  'Esophageal reflux' 'Adv eff sedat/hypnot NOS' 'Syncope and collapse']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43881
# 	['Hyp kid NOS w cr kid V' 'Hyp kid NOS w cr kid V'
#  'Dvrtcli colon w/o hmrhg' 'Gout NOS' 'Pneumonia, organism NOS'
#  'Hyperlipidemia NEC/NOS' 'Hyperlipidemia NEC/NOS' 'Hyposmolality'
#  'Hyposmolality' 'End stage renal disease' 'End stage renal disease'
#  'Secondary malig neo bone' 'Secondary malig neo bone'
#  'Second malig neo liver' 'Second malig neo liver'
#  'Secondary malig neo lung' 'Secondary malig neo lung'
#  'Chr blood loss anemia' 'Long-term use anticoagul'
#  'Gastrointest hemorr NOS' 'Obstructive sleep apnea'
#  'Hx-ven thrombosis/embols' 'Constipation NOS' 'Pulm embol/infarct NEC'
#  'Pulm embol/infarct NEC' 'Ac DVT/embl low ext NOS'
#  'Ac DVT/embl low ext NOS' 'Mal neo esophagus NEC' 'Mal neo esophagus NEC'
#  'Esophageal hemorrhage' 'Kidney transplant status'
#  'Kidney transplant status' 'Joint pain-unspec' 'Stomach ulcer NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43909
# 	['Atrial fibrillation' 'Pneumonia, organism NOS' 'Depressive disorder NEC'
#  'Sec mal neo brain/spine' 'Chr airway obstruct NEC'
#  'Mal neo bronch/lung NEC' 'Hypotension NOS' 'Neurohypophysis dis NEC'
#  'Respiratory arrest']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  43927
# 	['DMII wo cmp nt st uncntr' 'Crnry athrscl natve vssl'
#  'Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Asthma NOS'
#  'Ocl crtd art wo infrct' 'Status-post ptca' 'Prsnl hst colonic polyps'
#  'Chr tot occlus cor artry' 'Angina pectoris NEC/NOS'
#  'Prsnl hst urnr dsrd calc']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  44083
# 	['Hyperlipidemia NEC/NOS' 'Hypertension NOS' 'Hypertension NOS'
#  'Hypertension NOS' 'Anemia NOS' 'Anemia NOS' 'Pleural effusion NOS'
#  'Pleural effusion NOS' 'Mal neo stomach cardia' 'Pericardial disease NOS'
#  'Pericardial disease NOS' 'Hx-esophageal malignancy'
#  'Hx-esophageal malignancy' 'Cardiac tamponade']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  44154
# 	['Atrial fibrillation' 'Septicemia NOS' 'Severe sepsis'
#  'Food/vomit pneumonitis' 'Spinal stenosis NOS' 'Macular degeneration NOS'
#  'Arthropathy NOS-unspec' 'Asympt varicose veins']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  44212
# 	['Hyp kid NOS w cr kid V' 'Acute necrosis of liver' 'Hyperosmolality'
#  'Acute respiratry failure' 'Ac kidny fail, tubr necr'
#  'Hepatic encephalopathy' 'Severe sepsis' 'Ac alcoholic hepatitis'
#  'Urin tract infection NOS' 'Septic shock' 'Portal vein thrombosis'
#  'Pressure ulcer, low back' 'Anoxic brain damage'
#  'Meth susc Staph aur sept' 'Alcohol cirrhosis liver'
#  'Meth sus pneum d/t Staph' 'Paralytic ileus' 'Pressure ulcer,stage III'
#  'Ascites NEC' 'Immune thrombocyt purpra' 'Univrsl ulcertve colitis'
#  'Chron kidney dis stage V' 'Acq hemolytic anemia NOS']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  44222
# 	['Crnry athrscl natve vssl' 'Hyperlipidemia NEC/NOS'
#  'Acute kidney failure NOS' 'Paralysis agitans' 'Sinoatrial node dysfunct'
#  'Hy kid NOS w cr kid I-IV' 'DMII neuro nt st uncntrl'
#  'Neuropathy in diabetes' 'Chr kidney dis stage III' 'Spinal stenosis NOS'
#  'Adv eff cardiovasc NEC']
# ----------------------------------------------------------------------------------------------------
# Patient ID:  44228
# 	['Pneumonia, organism NOS' 'Severe sepsis' 'Anemia NOS' 'Septic shock'
#  'Hypothyroidism NOS' 'Int inf clstrdium dfcile' 'Second malig neo liver'
#  'E coli septicemia' 'Mal neo extrahepat ducts' 'Sec malig neo lg bowel'
#  'Phlbts sprfc vn up extrm']
# ----------------------------------------------------------------------------------------------------

# %%
d2 = pd.merge( patients, admissions, on="subject_id" )

# %%
patients.columns
# Out:
# Index(['subject_id', 'gender', 'dob', 'dod', 'dod_hosp', 'dod_ssn',
#        'expire_flag'],
#       dtype='object')

# %%
admissions.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'religion', 'marital_status', 'ethnicity',
#        'edregtime', 'edouttime', 'diagnosis', 'hospital_expire_flag',
#        'has_chartevents_data'],
#       dtype='object')

# %%
d2.columns
# Out:
# Index(['subject_id', 'gender', 'dob', 'dod', 'dod_hosp', 'dod_ssn',
#        'expire_flag', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'religion', 'marital_status', 'ethnicity',
#        'edregtime', 'edouttime', 'diagnosis', 'hospital_expire_flag',
#        'has_chartevents_data'],
#       dtype='object')

# %%
d2
# Out:
#      subject_id gender                  dob                  dod  \
# 0         10006      F  2094-03-05 00:00:00  2165-08-12 00:00:00
# 1         10011      F  2090-06-05 00:00:00  2126-08-28 00:00:00
# 2         10013      F  2038-09-03 00:00:00  2125-10-07 00:00:00
# 3         10017      F  2075-09-21 00:00:00  2152-09-12 00:00:00
# 4         10019      M  2114-06-20 00:00:00  2163-05-15 00:00:00
# ..          ...    ...                  ...                  ...
# 124       44083      M  2057-11-15 00:00:00  2114-02-20 00:00:00
# 125       44154      M  1878-05-14 00:00:00  2178-05-15 00:00:00
# 126       44212      F  2078-06-16 00:00:00  2124-01-29 00:00:00
# 127       44222      M  2107-06-27 00:00:00  2182-08-03 00:00:00
# 128       44228      F  2112-10-22 00:00:00  2171-04-14 00:00:00
#
#                 dod_hosp              dod_ssn  expire_flag  hadm_id  \
# 0    2165-08-12 00:00:00  2165-08-12 00:00:00            1   142345
# 1    2126-08-28 00:00:00                  NaN            1   105331
# 2    2125-10-07 00:00:00  2125-10-07 00:00:00            1   165520
# 3                    NaN  2152-09-12 00:00:00            1   199207
# 4    2163-05-15 00:00:00  2163-05-15 00:00:00            1   177759
# ..                   ...                  ...          ...      ...
# 124  2114-02-20 00:00:00  2114-02-20 00:00:00            1   198330
# 125  2178-05-15 00:00:00  2178-05-15 00:00:00            1   174245
# 126                  NaN  2124-01-29 00:00:00            1   163189
# 127  2182-08-03 00:00:00                  NaN            1   192189
# 128  2171-04-14 00:00:00                  NaN            1   103379
#
#                admittime            dischtime  ... insurance language  \
# 0    2164-10-23 21:09:00  2164-11-01 17:15:00  ...  Medicare      NaN
# 1    2126-08-14 22:32:00  2126-08-28 18:59:00  ...   Private      NaN
# 2    2125-10-04 23:36:00  2125-10-07 15:13:00  ...  Medicare      NaN
# 3    2149-05-26 17:19:00  2149-06-03 18:42:00  ...  Medicare      NaN
# 4    2163-05-14 20:43:00  2163-05-15 12:00:00  ...  Medicare      NaN
# ..                   ...                  ...  ...       ...      ...
# 124  2112-05-28 15:45:00  2112-06-07 16:50:00  ...   Private     ENGL
# 125  2178-05-14 20:29:00  2178-05-15 09:45:00  ...  Medicare     ENGL
# 126  2123-11-24 14:14:00  2123-12-30 14:31:00  ...  Medicare     ENGL
# 127  2180-07-19 06:55:00  2180-07-20 13:00:00  ...  Medicare     ENGL
# 128  2170-12-15 03:14:00  2170-12-24 18:00:00  ...   Private     ENGL
#
#               religion marital_status               ethnicity  \
# 0             CATHOLIC      SEPARATED  BLACK/AFRICAN AMERICAN
# 1             CATHOLIC         SINGLE   UNKNOWN/NOT SPECIFIED
# 2             CATHOLIC            NaN   UNKNOWN/NOT SPECIFIED
# 3             CATHOLIC       DIVORCED                   WHITE
# 4             CATHOLIC       DIVORCED                   WHITE
# ..                 ...            ...                     ...
# 124           CATHOLIC         SINGLE                   WHITE
# 125  PROTESTANT QUAKER        MARRIED                   WHITE
# 126       UNOBTAINABLE         SINGLE  BLACK/AFRICAN AMERICAN
# 127           CATHOLIC         SINGLE                   WHITE
# 128      NOT SPECIFIED         SINGLE                   WHITE
#
#                edregtime            edouttime  \
# 0    2164-10-23 16:43:00  2164-10-23 23:00:00
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3    2149-05-26 12:08:00  2149-05-26 19:45:00
# 4                    NaN                  NaN
# ..                   ...                  ...
# 124  2112-05-28 13:16:00  2112-05-28 17:30:00
# 125  2178-05-14 17:37:00  2178-05-14 22:08:00
# 126                  NaN                  NaN
# 127  2180-07-19 04:50:00  2180-07-19 08:23:00
# 128  2170-12-15 02:22:00  2170-12-15 05:25:00
#
#                                              diagnosis hospital_expire_flag  \
# 0                                               SEPSIS                    0
# 1                                          HEPATITIS B                    1
# 2                                               SEPSIS                    1
# 3                                     HUMERAL FRACTURE                    0
# 4                                  ALCOHOLIC HEPATITIS                    1
# ..                                                 ...                  ...
# 124                               PERICARDIAL EFFUSION                    0
# 125                              ALTERED MENTAL STATUS                    1
# 126  ACUTE RESPIRATORY DISTRESS SYNDROME;ACUTE RENA...                    0
# 127                                        BRADYCARDIA                    0
# 128                                        CHOLANGITIS                    0
#
#     has_chartevents_data
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 124                    1
# 125                    1
# 126                    1
# 127                    1
# 128                    1
#
# [129 rows x 24 columns]

# %%
d2.groupby([ 'insurance', 'diagnosis' ]).subject_id.count()
# Out:
# insurance   diagnosis
# Government  TACHYPNEA;TELEMETRY                                 1
# Medicaid    AROMEGLEY;BURKITTS LYMPHOMA                         1
#             BRAIN METASTASES                                    1
#             FAILURE TO THRIVE                                   1
#             HEPATIC ENCEP                                       1
#                                                                ..
# Private     SHORTNESS OF BREATH                                 1
#             STATUS POST MOTOR VEHICLE ACCIDENT WITH INJURIES    1
#             TRACHEAL STENOSIS                                   1
#             UPPER GI BLEED                                      1
#             UROSEPSIS                                           1
# Name: subject_id, Length: 101, dtype: int64

# %%
d2.groupby([ 'insurance', 'diagnosis' ]).subject_id.count().max()
# Out:
# 9

# %%
d2.groupby([ 'insurance', 'diagnosis' ]).subject_id.count().argmax()
# Out:
# 61

# %%
d2.groupby([ 'insurance', 'diagnosis' ]).subject_id.count().index[61]
# Out:
# ('Medicare', 'SEPSIS')
